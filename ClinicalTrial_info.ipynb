# %%
## DTx clinical trials search strategy
# import for Clinicaltrial.gov or Chinese Clinical Trials Registry
from bs4 import BeautifulSoup 
import re  
import urllib.request, urllib.error  
import xlwt  
import sqlite3 
from selenium import webdriver 
from selenium.webdriver.common.by import By  
from selenium.webdriver import ChromeOptions
from selenium.webdriver.common.keys import Keys   
from selenium.webdriver.support.wait import WebDriverWait  
from selenium.webdriver.support import expected_conditions as EC  
from selenium.common.exceptions import TimeoutException, NoSuchElementException
import time
from bs4 import BeautifulSoup
import sys
import json

# %%
### import for Chinese Clinical Trials Registry

## search terms in Chinese(utf-8)
# 远程 (%E8%BF%9C%E7%A8%8B),互联网 (%E4%BA%92%E8%81%94%E7%BD%91), 移动 (%E7%A7%BB%E5%8A%A8), 虚拟现实 (%E8%99%9A%E6%8B%9F%E7%8E%B0%E5%AE%9E), 应用程序 (%E5%BA%94%E7%94%A8%E7%A8%8B%E5%BA%8F), 小程序 (%E5%B0%8F%E7%A8%8B%E5%BA%8F), 数字疗法 (%E6%95%B0%E5%AD%97%E7%96%97%E6%B3%95)


## define characteristics 

# basic characteristics
RegistrationN_list = [], DateR_list = [], ScientificT_list = [], Applicant_list = []
StudyL_list =[], ApplicantI_list = [], AffiliationL_list = []
SourceF_list = [], TargetD_list = [], StudyT_list = [], StudyP_list = [], StudyD_list = [], StudyO_list = []
StudyTi_from_list = [], StudyTi_to_list = [], RecruitTi_from_list = [], RecruitTi_to_list = []
Recruiting_status = [], Age_min = [], Age_max = [], Gender = [], Randomization = [], Blind = []

# group, sample size, intervention
G1 = [], G1_Ssize = [], G1_intervention = [], G2 = [], G2_Ssize = [], G2_intervention = []
G3 = [], G3_Ssize = [], G3_intervention = [], G4 = [], G4_Ssize = [], G4_intervention = []
G5 = [], G5_Ssize = [], G5_intervention = []

# implementation site, level, location
S_hospital = [], S_level = [], S_Province = [], S1_hospital = [], S1_level = [], S1_Province = []
S2_hospital = [], S2_level = [], S2_Province = [], S3_hospital = [], S3_level = [], S3_Province = []
S4_hospital = [], S4_level = [], S4_Province = [], S5_hospital = [], S5_level = [], S5_Province = []
S6_hospital = [], S6_level = [], S6_Province = [], S7_hospital = [], S7_level = [], S7_Province = []
S8_hospital = [], S8_level = [], S8_Province = [], S9_hospital = [], S9_level = [], S9_Province = []

# outcome, type, time_point, method
O1 = [], O1_type = [], O1_point = [], O1_method = [], O2 = [], O2_type = [], O2_point = [], O2_method = []
O3 = [], O3_type = [], O3_point = [], O3_method = [], O4 = [], O4_type = [], O4_point = [], O4_method = []
O5 = [], O5_type = [], O5_point = [], O5_method = [], O6 = [], O6_type = [], O6_point = [], O6_method = []
O7 = [], O7_type = [], O7_point = [], O7_method = [], O8 = [], O8_type = [], O8_point = [], O8_method = []
O9 = [], O9_type = [], O9_point = [], O9_method = [], O10 = [], O10_type = [], O10_point = [], O10_method = []

# %%
## get clinical trials registration number list and load matching information

#url_list = []

class spider():
    def __init__(self):
        # url
        # self.url = 'https://www.chictr.org.cn/searchproj.html?page=2&title=%E8%BF%9C%E7%A8%8B&officialname=&subjectid=&regstatus=&regno=&secondaryid=&applier=&studyleader=&createyear=&sponsor=&secsponsor=&sourceofspends=&studyailment=&studyailmentcode=&studytype=&studystage=&studydesign=&recruitmentstatus=&gender=&agreetosign=&measure=&country=&province=&city=&institution=&institutionlevel=&intercode=&ethicalcommitteesanction=&whetherpublic=&minstudyexecutetime=&maxstudyexecutetime=&btngo=btn'
        self.opt = webdriver.ChromeOptions()  
        self.opt.add_experimental_option('excludeSwitches', ['enable-automation']) 
        self.browser = webdriver.Chrome(options=self.opt)
        options = webdriver.ChromeOptions()  
        options.add_experimental_option("prefs", {"profile.managed_default_content_settings.images": 2})

    def get_lc(self,url,j):
        self.browser.get(url)

        wait = WebDriverWait(self.browser, 280)
        wait.until(EC.presence_of_element_located((By.ID, 'topic')))

        # text_input = self.browser.find_element(By.ID, 'topic')
        # text_input.send_keys('远程')
        # time.sleep(10)
        #self.browser.find_element(By.XPATH, '//*[@id="handle-search"]').click()
        time.sleep(1)
        if j==1:
            self.browser.find_element(By.XPATH, '/html/body/div[1]/div/div[3]/table/tbody/tr[2]/td[3]/a').click()
        elif j==2:
            self.browser.find_element(By.XPATH, '/html/body/div[1]/div/div[3]/table/tbody/tr[3]/td[3]/a').click()
        elif j==3:
            self.browser.find_element(By.XPATH, '/html/body/div[1]/div/div[3]/table/tbody/tr[4]/td[3]/a').click()
        elif j==4:
            self.browser.find_element(By.XPATH, '/html/body/div[1]/div/div[3]/table/tbody/tr[5]/td[3]/a').click()
        elif j==5:
            self.browser.find_element(By.XPATH, '/html/body/div[1]/div/div[3]/table/tbody/tr[6]/td[3]/a').click()
        elif j==6:
            self.browser.find_element(By.XPATH, '/html/body/div[1]/div/div[3]/table/tbody/tr[7]/td[3]/a').click()
        elif j==7:
            self.browser.find_element(By.XPATH, '/html/body/div[1]/div/div[3]/table/tbody/tr[8]/td[3]/a').click()
        elif j==8:
            self.browser.find_element(By.XPATH, '/html/body/div[1]/div/div[3]/table/tbody/tr[9]/td[3]/a').click()
        elif j==9:
            self.browser.find_element(By.XPATH, '/html/body/div[1]/div/div[3]/table/tbody/tr[10]/td[3]/a').click()
        elif j==10:
            self.browser.find_element(By.XPATH, '/html/body/div[1]/div/div[3]/table/tbody/tr[11]/td[3]/a').click()


        time.sleep(1)
    def get_data(self):
        data=self.browser.page_source
        
        browser = webdriver.Chrome(executable_path='path/to/chromedriver')
        url_list.append(browser.current_url)
        print(browser.current_url)
        
        try:
            RegistrationN_list.append(self.browser.find_element(By.XPATH, '/html/body/div[1]/div/div[3]/div[3]/table/tbody/tr[1]/td[2]').text)
            print('success')
        except NoSuchElementException:
            RegistrationN_list.append('NA')
            print('None')
        try:
            DateR_list.append(self.browser.find_element(By.XPATH, '/html/body/div[1]/div/div[3]/div[3]/table/tbody/tr[3]/td[2]').text)
            print('success')
        except NoSuchElementException:
            DateR_list.append('NA')
            print('None')
        try:
            ScientificT_list.append(self.browser.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[3]/table/tbody/tr[10]/td[2]/p').text)
            print('success')
        except NoSuchElementException:
            ScientificT_list.append('NA')
            print('None')
        try:
            ScientificT_en_list.append(self.browser.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[3]/table/tbody/tr[11]/td[2]/p').text)
            print('success')
        except NoSuchElementException:
            ScientificT_en_list.append('NA')
            print('None')    
        try:
            Applicant_list.append(self.browser.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[4]/table/tbody/tr[1]/td[2]/p').text)
            print('success')
        except NoSuchElementException:
            Applicant_list.append('NA')
            print('None')      
        try:
            StudyL_list.append(self.browser.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[4]/table/tbody/tr[1]/td[4]/p').text)
            print('success')
        except NoSuchElementException:
            StudyL_list.append('NA')
            print('None')  
        try:
            ApplicantI_list.append(self.browser.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[4]/table/tbody/tr[10]/td[2]/p').text)
            print('success')
        except NoSuchElementException:
            ApplicantI_list.append('NA')
            print('None')  
        try:
            ApplicantI_en_list.append(self.browser.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[4]/table/tbody/tr[11]/td[2]/p').text)
            print('success')
        except NoSuchElementException:
            ApplicantI_en_list.append('NA')
            print('None')
        try:
            AffiliationL_list.append(self.browser.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[4]/table/tbody/tr[12]/td[2]/p').text)
            print('success')
        except NoSuchElementException:
            AffiliationL_list.append('NA')
            print('None')
        try:
            AffiliationL_en_list.append(self.browser.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[4]/table/tbody/tr[13]/td[2]/p').text)
            print('success')
        except NoSuchElementException:
            AffiliationL_en_list.append('NA')
            print('None')
        try:
            SourceF_list.append(self.browser.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[6]/table[1]/tbody/tr[6]/td[2]/p').text)
            print('success')
        except NoSuchElementException:
            SourceF_list.append('NA')
            print('None')
        try:
            TargetD_list.append(self.browser.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[6]/table[1]/tbody/tr[8]/td[2]/p').text)
            print('success')
        except NoSuchElementException:
            TargetD_list.append('NA')
            print('None')
        try:
            TargetD_en_list.append(self.browser.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[6]/table[1]/tbody/tr[9]/td[2]/p').text)
            print('success')
        except NoSuchElementException:
            TargetD_en_list.append('NA')
            print('None')
        try:
            StudyT_list.append(self.browser.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[6]/table[1]/tbody/tr[12]/td[2]/p').text)
            print('success')
        except NoSuchElementException:
            StudyT_list.append('NA')
            print('None')
        try:
            StudyP_list.append(self.browser.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[6]/table[1]/tbody/tr[14]/td[2]/span').text)
            print('success')
        except NoSuchElementException:
            StudyP_list.append('NA')
            print('None')
        try:
            StudyD_list.append(self.browser.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[6]/table[1]/tbody/tr[16]/td[2]/p').text)
            print('success')
        except NoSuchElementException:
            StudyD_list.append('NA')
            print('None')
        try:
            StudyO_list.append(self.browser.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[6]/table[1]/tbody/tr[18]/td[2]/p').text)
            print('success')
        except NoSuchElementException:
            StudyO_list.append('NA')
            print('None')
        try:
            StudyTi_from_list.append(self.browser.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[6]/table[2]/tbody/tr/td[2]/span[3]').text)
            print('success')
        except NoSuchElementException:
            StudyTi_from_list.append('NA')
            print('None')
        try:
            StudyTi_to_list.append(self.browser.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[6]/table[2]/tbody/tr/td[2]/span[6]').text)
            print('success')
        except NoSuchElementException:
            StudyTi_to_list.append('NA')
            print('None')
        try:
            RecruitTi_from_list.append(self.browser.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[6]/table[2]/tbody/tr/td[4]/span[3]').text)
            print('success')
        except NoSuchElementException:
            RecruitTi_from_list.append('NA')
            print('None')
        try:
            RecruitTi_to_list.append(self.browser.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[6]/table[2]/tbody/tr/td[4]/span[6]').text)
            print('success')
        except NoSuchElementException:
            RecruitTi_to_list.append('NA')
            print('None')
        try:
            G1.append(self.browser.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[7]/table/tbody/tr/td[2]/table[1]/tbody/tr[1]/td[2]/p').text)
            print('success')
        except NoSuchElementException:
            G1.append('NA')
            print('None')
        try:
            G1_Ssize.append(self.browser.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[7]/table/tbody/tr/td[2]/table[1]/tbody/tr[1]/td[4]').text)
            print('success')
        except NoSuchElementException:
            G1_Ssize.append('NA')
            print('None')            
        try:
            G1_intervention.append(self.browser.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[7]/table/tbody/tr/td[2]/table[1]/tbody/tr[3]/td[2]/p').text)
            print('success')
        except NoSuchElementException:
            G1_intervention.append('NA')
            print('None')          
        try:
            G2.append(self.browser.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[7]/table/tbody/tr/td[2]/table[2]/tbody/tr[1]/td[2]/p').text)
            print('success')
        except NoSuchElementException:
            G2.append('NA')
            print('None')
        try:
            G2_Ssize.append(self.browser.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[7]/table/tbody/tr/td[2]/table[2]/tbody/tr[1]/td[4]').text)
            print('success')
        except NoSuchElementException:
            G2_Ssize.append('NA')
            print('None')            
        try:
            G2_intervention.append(self.browser.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[7]/table/tbody/tr/td[2]/table[2]/tbody/tr[3]/td[2]/p').text)
            print('success')
        except NoSuchElementException:
            G2_intervention.append('NA')
            print('None') 
        try:
            G3.append(self.browser.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[7]/table/tbody/tr/td[2]/table[3]/tbody/tr[1]/td[2]/p').text)
            print('success')
        except NoSuchElementException:
            G3.append('NA')
            print('None')
        try:
            G3_Ssize.append(self.browser.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[7]/table/tbody/tr/td[2]/table[3]/tbody/tr[1]/td[4]').text)
            print('success')
        except NoSuchElementException:
            G3_Ssize.append('NA')
            print('None')            
        try:
            G3_intervention.append(self.browser.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[7]/table/tbody/tr/td[2]/table[3]/tbody/tr[3]/td[2]/p').text)
            print('success')
        except NoSuchElementException:
            G3_intervention.append('NA')
            print('None')          
        try:
            G4.append(self.browser.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[7]/table/tbody/tr/td[2]/table[4]/tbody/tr[1]/td[2]/p').text)
            print('success')
        except NoSuchElementException:
            G4.append('NA')
            print('None')
        try:
            G4_Ssize.append(self.browser.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[7]/table/tbody/tr/td[2]/table[4]/tbody/tr[1]/td[4]').text)
            print('success')
        except NoSuchElementException:
            G4_Ssize.append('NA')
            print('None')            
        try:
            G4_intervention.append(self.browser.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[7]/table/tbody/tr/td[2]/table[4]/tbody/tr[3]/td[2]/p').text)
            print('success')
        except NoSuchElementException:
            G4_intervention.append('NA')
            print('None')   
        try:
            G5.append(self.browser.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[7]/table/tbody/tr/td[2]/table[5]/tbody/tr[1]/td[2]/p').text)
            print('success')
        except NoSuchElementException:
            G5.append('NA')
            print('None')
        try:
            G5_Ssize.append(self.browser.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[7]/table/tbody/tr/td[2]/table[5]/tbody/tr[1]/td[4]').text)
            print('success')
        except NoSuchElementException:
            G5_Ssize.append('NA')
            print('None')            
        try:
            G5_intervention.append(self.browser.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[7]/table/tbody/tr/td[2]/table[5]/tbody/tr[3]/td[2]/p').text)
            print('success')
        except NoSuchElementException:
            G5_intervention.append('NA')
            print('None')
            
        try:
            S_hospital.append(self.browser.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[8]/table/tbody/tr/td[2]/table/tbody/tr[3]/td[2]').text)
            print('success')
        except NoSuchElementException:
            S_hospital.append('NA')
            print('None')   
        try:
            S_level.append(self.browser.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[8]/table/tbody/tr/td[2]/table/tbody/tr[3]/td[4]').text)
            print('success')
        except NoSuchElementException:
            S_level.append('NA')
            print('None')                 
        try:
            S_Province.append(self.browser.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[8]/table/tbody/tr/td[2]/table/tbody/tr[1]/td[4]').text)
            print('success')
        except NoSuchElementException:
            S_Province.append('NA')
            print('None')             
        try:
            S1_hospital.append(self.browser.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[8]/table/tbody/tr/td[2]/table[1]/tbody/tr[3]/td[2]').text)
            print('success')
        except NoSuchElementException:
            S1_hospital.append('NA')
            print('None')    
        try:
            S1_level.append(self.browser.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[8]/table/tbody/tr/td[2]/table[1]/tbody/tr[3]/td[4]').text)
            print('success')
        except NoSuchElementException:
            S1_level.append('NA')
            print('None')                
        try:
            S1_Province.append(self.browser.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[8]/table/tbody/tr/td[2]/table[1]/tbody/tr[1]/td[4]').text)
            print('success')
        except NoSuchElementException:
            S1_Province.append('NA')
            print('None')     
        try:
            S2_hospital.append(self.browser.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[8]/table/tbody/tr/td[2]/table[2]/tbody/tr[3]/td[2]').text)
            print('success')
        except NoSuchElementException:
            S2_hospital.append('NA')
            print('None')  
        try:
            S2_level.append(self.browser.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[8]/table/tbody/tr/td[2]/table[2]/tbody/tr[3]/td[4]').text)
            print('success')
        except NoSuchElementException:
            S2_level.append('NA')
            print('None')     
        try:
            S2_Province.append(self.browser.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[8]/table/tbody/tr/td[2]/table[2]/tbody/tr[1]/td[4]').text)
            print('success')
        except NoSuchElementException:
            S2_Province.append('NA')
            print('None')
        try:
            S3_hospital.append(self.browser.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[8]/table/tbody/tr/td[2]/table[3]/tbody/tr[3]/td[2]').text)
            print('success')
        except NoSuchElementException:
            S3_hospital.append('NA')
            print('None')    
        try:
            S3_level.append(self.browser.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[8]/table/tbody/tr/td[2]/table[3]/tbody/tr[3]/td[4]').text)
            print('success')
        except NoSuchElementException:
            S3_level.append('NA')
            print('None')                
        try:
            S3_Province.append(self.browser.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[8]/table/tbody/tr/td[2]/table[3]/tbody/tr[1]/td[4]').text)
            print('success')
        except NoSuchElementException:
            S3_Province.append('NA')
            print('None')            
        try:
            S4_hospital.append(self.browser.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[8]/table/tbody/tr/td[2]/table[4]/tbody/tr[3]/td[2]').text)
            print('success')
        except NoSuchElementException:
            S4_hospital.append('NA')
            print('None')   
        try:
            S4_level.append(self.browser.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[8]/table/tbody/tr/td[2]/table[4]/tbody/tr[3]/td[4]').text)
            print('success')
        except NoSuchElementException:
            S4_level.append('NA')
            print('None')                 
        try:
            S4_Province.append(self.browser.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[8]/table/tbody/tr/td[2]/table[4]/tbody/tr[1]/td[4]').text)
            print('success')
        except NoSuchElementException:
            S4_Province.append('NA')
            print('None') 
        try:
            S5_hospital.append(self.browser.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[8]/table/tbody/tr/td[2]/table[5]/tbody/tr[3]/td[2]').text)
            print('success')
        except NoSuchElementException:
            S5_hospital.append('NA')
            print('None')   
        try:
            S5_level.append(self.browser.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[8]/table/tbody/tr/td[2]/table[5]/tbody/tr[3]/td[4]').text)
            print('success')
        except NoSuchElementException:
            S5_level.append('NA')
            print('None')                
        try:
            S5_Province.append(self.browser.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[8]/table/tbody/tr/td[2]/table[5]/tbody/tr[1]/td[4]').text)
            print('success')
        except NoSuchElementException:
            S5_Province.append('NA')
            print('None') 
        try:
            S6_hospital.append(self.browser.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[8]/table/tbody/tr/td[2]/table[6]/tbody/tr[3]/td[2]').text)
            print('success')
        except NoSuchElementException:
            S6_hospital.append('NA')
            print('None')    
        try:
            S6_level.append(self.browser.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[8]/table/tbody/tr/td[2]/table[6]/tbody/tr[3]/td[4]').text)
            print('success')
        except NoSuchElementException:
            S6_level.append('NA')
            print('None')                 
        try:
            S6_Province.append(self.browser.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[8]/table/tbody/tr/td[2]/table[6]/tbody/tr[1]/td[4]').text)
            print('success')
        except NoSuchElementException:
            S6_Province.append('NA')
            print('None')           
        try:
            S7_hospital.append(self.browser.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[8]/table/tbody/tr/td[2]/table[7]/tbody/tr[3]/td[2]').text)
            print('success')
        except NoSuchElementException:
            S7_hospital.append('NA')
            print('None')    
        try:
            S7_level.append(self.browser.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[8]/table/tbody/tr/td[2]/table[7]/tbody/tr[3]/td[4]').text)
            print('success')
        except NoSuchElementException:
            S7_level.append('NA')
            print('None')                
        try:
            S7_Province.append(self.browser.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[8]/table/tbody/tr/td[2]/table[7]/tbody/tr[1]/td[4]').text)
            print('success')
        except NoSuchElementException:
            S7_Province.append('NA')
            print('None')       
        try:
            S8_hospital.append(self.browser.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[8]/table/tbody/tr/td[2]/table[8]/tbody/tr[3]/td[2]').text)
            print('success')
        except NoSuchElementException:
            S8_hospital.append('NA')
            print('None')   
        try:
            S8_level.append(self.browser.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[8]/table/tbody/tr/td[2]/table[8]/tbody/tr[3]/td[4]').text)
            print('success')
        except NoSuchElementException:
            S8_level.append('NA')
            print('None')                 
        try:
            S8_Province.append(self.browser.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[8]/table/tbody/tr/td[2]/table[8]/tbody/tr[1]/td[4]').text)
            print('success')
        except NoSuchElementException:
            S8_Province.append('NA')
            print('None')
        try:
            S9_hospital.append(self.browser.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[8]/table/tbody/tr/td[2]/table[9]/tbody/tr[3]/td[2]').text)
            print('success')
        except NoSuchElementException:
            S9_hospital.append('NA')
            print('None')   
        try:
            S9_level.append(self.browser.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[8]/table/tbody/tr/td[2]/table[9]/tbody/tr[3]/td[4]').text)
            print('success')
        except NoSuchElementException:
            S9_level.append('NA')
            print('None')                 
        try:
            S9_Province.append(self.browser.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[8]/table/tbody/tr/td[2]/table[9]/tbody/tr[1]/td[4]').text)
            print('success')
        except NoSuchElementException:
            S9_Province.append('NA')
            print('None')        
        try:
            S10_hospital.append(self.browser.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[8]/table/tbody/tr/td[2]/table[10]/tbody/tr[3]/td[2]').text)
            print('success')
        except NoSuchElementException:
            S10_hospital.append('NA')
            print('None')    
        try:
            S10_level.append(self.browser.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[8]/table/tbody/tr/td[2]/table[10]/tbody/tr[3]/td[4]').text)
            print('success')
        except NoSuchElementException:
            S10_level.append('NA')
            print('None')                
        try:
            S10_Province.append(self.browser.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[8]/table/tbody/tr/td[2]/table[10]/tbody/tr[1]/td[4]').text)
            print('success')
        except NoSuchElementException:
            S10_Province.append('NA')
            print('None')                    
        try:
            O1.append(self.browser.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[9]/table/tbody/tr/td[2]/div/table[1]/tbody/tr[1]/td[2]/p').text)
            print('success')
        except NoSuchElementException:
            O1.append('NA')
            print('None')    
        try:
            O1_type.append(self.browser.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[9]/table/tbody/tr/td[2]/div/table[1]/tbody/tr[1]/td[4]/p').text)
            print('success')
        except NoSuchElementException:
            O1_type.append('NA')
            print('None')
        try:
            O1_point.append(self.browser.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[9]/table/tbody/tr/td[2]/div/table[1]/tbody/tr[3]/td[2]/p').text)
            print('success')
        except NoSuchElementException:
            O1_point.append('NA')
            print('None')   
        try:
            O1_method.append(self.browser.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[9]/table/tbody/tr/td[2]/div/table[1]/tbody/tr[3]/td[4]/p').text)
            print('success')
        except NoSuchElementException:
            O1_method.append('NA')
            print('None')
        try:
            O2.append(self.browser.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[9]/table/tbody/tr/td[2]/div/table[2]/tbody/tr[1]/td[2]/p').text)
            print('success')
        except NoSuchElementException:
            O2.append('NA')
            print('None')    
        try:
            O2_type.append(self.browser.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[9]/table/tbody/tr/td[2]/div/table[2]/tbody/tr[1]/td[4]/p').text)
            print('success')
        except NoSuchElementException:
            O2_type.append('NA')
            print('None')
        try:
            O2_point.append(self.browser.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[9]/table/tbody/tr/td[2]/div/table[2]/tbody/tr[3]/td[2]/p').text)
            print('success')
        except NoSuchElementException:
            O2_point.append('NA')
            print('None')    
        try:
            O2_method.append(self.browser.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[9]/table/tbody/tr/td[2]/div/table[2]/tbody/tr[3]/td[4]/p').text)
            print('success')
        except NoSuchElementException:
            O2_method.append('NA')
            print('None')
        try:
            O3.append(self.browser.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[9]/table/tbody/tr/td[2]/div/table[3]/tbody/tr[1]/td[2]/p').text)
            print('success')
        except NoSuchElementException:
            O3.append('NA')
            print('None')   
        try:
            O3_type.append(self.browser.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[9]/table/tbody/tr/td[2]/div/table[3]/tbody/tr[1]/td[4]/p').text)
            print('success')
        except NoSuchElementException:
            O3_type.append('NA')
            print('None')
        try:
            O3_point.append(self.browser.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[9]/table/tbody/tr/td[2]/div/table[3]/tbody/tr[3]/td[2]/p').text)
            print('success')
        except NoSuchElementException:
            O3_point.append('NA')
            print('None')    
        try:
            O3_method.append(self.browser.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[9]/table/tbody/tr/td[2]/div/table[3]/tbody/tr[3]/td[4]/p').text)
            print('success')
        except NoSuchElementException:
            O3_method.append('NA')
            print('None')           
        try:
            O4.append(self.browser.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[9]/table/tbody/tr/td[2]/div/table[4]/tbody/tr[1]/td[2]/p').text)
            print('success')
        except NoSuchElementException:
            O4.append('NA')
            print('None')     
        try:
            O4_type.append(self.browser.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[9]/table/tbody/tr/td[2]/div/table[4]/tbody/tr[1]/td[4]/p').text)
            print('success')
        except NoSuchElementException:
            O4_type.append('NA')
            print('None')
        try:
            O4_point.append(self.browser.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[9]/table/tbody/tr/td[2]/div/table[4]/tbody/tr[3]/td[2]/p').text)
            print('success')
        except NoSuchElementException:
            O4_point.append('NA')
            print('None')   
        try:
            O4_method.append(self.browser.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[9]/table/tbody/tr/td[2]/div/table[4]/tbody/tr[3]/td[4]/p').text)
            print('success')
        except NoSuchElementException:
            O4_method.append('NA')
            print('None')          
        try:
            O5.append(self.browser.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[9]/table/tbody/tr/td[2]/div/table[5]/tbody/tr[1]/td[2]/p').text)
            print('success')
        except NoSuchElementException:
            O5.append('NA')
            print('None')    
        try:
            O5_type.append(self.browser.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[9]/table/tbody/tr/td[2]/div/table[5]/tbody/tr[1]/td[4]/p').text)
            print('success')
        except NoSuchElementException:
            O5_type.append('NA')
            print('None')
        try:
            O5_point.append(self.browser.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[9]/table/tbody/tr/td[2]/div/table[5]/tbody/tr[3]/td[2]/p').text)
            print('success')
        except NoSuchElementException:
            O5_point.append('NA')
            print('None')     
        try:
            O5_method.append(self.browser.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[9]/table/tbody/tr/td[2]/div/table[5]/tbody/tr[3]/td[4]/p').text)
            print('success')
        except NoSuchElementException:
            O5_method.append('NA')
            print('None')
        try:
            O6.append(self.browser.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[9]/table/tbody/tr/td[2]/div/table[6]/tbody/tr[1]/td[2]/p').text)
            print('success')
        except NoSuchElementException:
            O6.append('NA')
            print('None')   
        try:
            O6_type.append(self.browser.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[9]/table/tbody/tr/td[2]/div/table[6]/tbody/tr[1]/td[4]/p').text)
            print('success')
        except NoSuchElementException:
            O6_type.append('NA')
            print('None')
        try:
            O6_point.append(self.browser.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[9]/table/tbody/tr/td[2]/div/table[6]/tbody/tr[3]/td[2]/p').text)
            print('success')
        except NoSuchElementException:
            O6_point.append('NA')
            print('None')   
        try:
            O6_method.append(self.browser.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[9]/table/tbody/tr/td[2]/div/table[6]/tbody/tr[3]/td[4]/p').text)
            print('success')
        except NoSuchElementException:
            O6_method.append('NA')
            print('None')
        try:
            O7.append(self.browser.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[9]/table/tbody/tr/td[2]/div/table[7]/tbody/tr[1]/td[2]/p').text)
            print('success')
        except NoSuchElementException:
            O7.append('NA')
            print('None')    
        try:
            O7_type.append(self.browser.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[9]/table/tbody/tr/td[2]/div/table[7]/tbody/tr[1]/td[4]/p').text)
            print('success')
        except NoSuchElementException:
            O7_type.append('NA')
            print('None')
        try:
            O7_point.append(self.browser.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[9]/table/tbody/tr/td[2]/div/table[7]/tbody/tr[3]/td[2]/p').text)
            print('success')
        except NoSuchElementException:
            O7_point.append('NA')
            print('None')   
        try:
            O7_method.append(self.browser.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[9]/table/tbody/tr/td[2]/div/table[7]/tbody/tr[3]/td[4]/p').text)
            print('success')
        except NoSuchElementException:
            O7_method.append('NA')
            print('None')         
        try:
            O8.append(self.browser.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[9]/table/tbody/tr/td[2]/div/table[8]/tbody/tr[1]/td[2]/p').text)
            print('success')
        except NoSuchElementException:
            O8.append('NA')
            print('None')     
        try:
            O8_type.append(self.browser.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[9]/table/tbody/tr/td[2]/div/table[8]/tbody/tr[1]/td[4]/p').text)
            print('success')
        except NoSuchElementException:
            O8_type.append('NA')
            print('None')
        try:
            O8_point.append(self.browser.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[9]/table/tbody/tr/td[2]/div/table[8]/tbody/tr[3]/td[2]/p').text)
            print('success')
        except NoSuchElementException:
            O8_point.append('NA')
            print('None')   
        try:
            O8_method.append(self.browser.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[9]/table/tbody/tr/td[2]/div/table[8]/tbody/tr[3]/td[4]/p').text)
            print('success')
        except NoSuchElementException:
            O8_method.append('NA')
            print('None')
        try:
            O9.append(self.browser.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[9]/table/tbody/tr/td[2]/div/table[9]/tbody/tr[1]/td[2]/p').text)
            print('success')
        except NoSuchElementException:
            O9.append('NA')
            print('None')   
        try:
            O9_type.append(self.browser.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[9]/table/tbody/tr/td[2]/div/table[9]/tbody/tr[1]/td[4]/p').text)
            print('success')
        except NoSuchElementException:
            O9_type.append('NA')
            print('None')
        try:
            O9_point.append(self.browser.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[9]/table/tbody/tr/td[2]/div/table[9]/tbody/tr[3]/td[2]/p').text)
            print('success')
        except NoSuchElementException:
            O9_point.append('NA')
            print('None')    
        try:
            O9_method.append(self.browser.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[9]/table/tbody/tr/td[2]/div/table[9]/tbody/tr[3]/td[4]/p').text)
            print('success')
        except NoSuchElementException:
            O9_method.append('NA')
            print('None')           
        try:
            O10.append(self.browser.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[9]/table/tbody/tr/td[2]/div/table[10]/tbody/tr[1]/td[2]/p').text)
            print('success')
        except NoSuchElementException:
            O10.append('NA')
            print('None')   
        try:
            O10_type.append(self.browser.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[9]/table/tbody/tr/td[2]/div/table[10]/tbody/tr[1]/td[4]/p').text)
            print('success')
        except NoSuchElementException:
            O10_type.append('NA')
            print('None')
        try:
            O10_point.append(self.browser.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[9]/table/tbody/tr/td[2]/div/table[10]/tbody/tr[3]/td[2]/p').text)
            print('success')
        except NoSuchElementException:
            O10_point.append('NA')
            print('None')   
        try:
            O10_method.append(self.browser.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[9]/table/tbody/tr/td[2]/div/table[10]/tbody/tr[3]/td[4]/p').text)
            print('success')
        except NoSuchElementException:
            O10_method.append('NA')
            print('None')
        try:
            ethic.append(self.browser.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[5]/table/tbody[1]/tr[1]/td[2]/p').text)
            print('success')
        except NoSuchElementException:
            ethic.append('NA')
            print('None')  
        try:
            Recruiting_status.append(self.browser.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[11]/table/tbody/tr[1]/td[2]/p[2]').text)
            print('success')
        except NoSuchElementException:
            Recruiting_status.append('NA')
            print('None')
        try:
            Age_min.append(self.browser.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[11]/table/tbody/tr[1]/td[4]/table/tbody/tr[1]/td[2]').text)
            print('success')
        except NoSuchElementException:
            Age_min.append('NA')
            print('None')   
        try:
            Age_max.append(self.browser.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[11]/table/tbody/tr[1]/td[4]/table/tbody/tr[2]/td[2]').text)
            print('success')
        except NoSuchElementException:
            Age_max.append('NA')
            print('None')  
        try:
            Gender.append(self.browser.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[11]/table/tbody/tr[2]/td[2]/p').text)
            print('success')
        except NoSuchElementException:
            Gender.append('NA')
            print('None')
        try:
            Randomization.append(self.browser.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[11]/table/tbody/tr[3]/td[2]/p').text)
            print('success')
        except NoSuchElementException:
            Randomization.append('NA')
            print('None')  
        try:
            Randomization_en.append(self.browser.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[11]/table/tbody/tr[4]/td[2]/p').text)
            print('success')
        except NoSuchElementException:
            Randomization_en.append('NA')
            print('None')
        try:
            Blind.append(self.browser.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[13]/table/tbody[1]/tr[1]/td[2]/p').text)
            print('success')
        except NoSuchElementException:
            Blind.append('NA')
            print('None')   


        
if __name__ == '__main__':
    for i in range(1,25):
        print("现在是第{}页".format(i))
        #### change search terms
        url='https://www.chictr.org.cn/searchproj.html?page={}&title=%E6%95%B0%E5%AD%97%E7%96%97%E6%B3%95&officialname=&subjectid=&regstatus=&regno=&secondaryid=&applier=&studyleader=&createyear=&sponsor=&secsponsor=&sourceofspends=&studyailment=&studyailmentcode=&studytype=&studystage=&studydesign=&recruitmentstatus=&gender=&agreetosign=&measure=&country=&province=&city=&institution=&institutionlevel=&intercode=&ethicalcommitteesanction=&whetherpublic=&minstudyexecutetime=&maxstudyexecutetime=&btngo=btn'.format(i)
        s = spider()
        for j in range(1,11):
            print("现在是第{}个数据".format(j))           
            s.get_lc(url,j)
            s.get_data()

# %%
data = [RegistrationN_list,DateR_list,ScientificT_list,ScientificT_en_list,Applicant_list,StudyL_list,
ApplicantI_list,ApplicantI_en_list,AffiliationL_list,AffiliationL_en_list,SourceF_list,TargetD_list,TargetD_en_list,
StudyT_list,StudyP_list,StudyD_list,StudyO_list,StudyTi_from_list,StudyTi_to_list,RecruitTi_from_list,RecruitTi_to_list,
G1,G1_Ssize,G1_intervention,G2,G2_Ssize,G2_intervention,G3,G3_Ssize,G3_intervention,G4,G4_Ssize,G4_intervention,G5,G5_Ssize,G5_intervention,
S_hospital,S_level,S_level_en,S_Province,S1_hospital,S1_level,S1_Province,
S2_hospital,S2_level,S2_Province,S3_hospital,S3_level,S3_Province,
S4_hospital,S4_level,S4_Province,S5_hospital,S5_level,S5_Province,
S6_hospital,S6_level,S6_Province,S7_hospital,S7_level,S7_Province,
S8_hospital,S8_level,S8_Province,S9_hospital,S9_level,S9_Province,S10_hospital,S10_level,S10_Province,
O1,O1_type,O1_point,O1_method,O2,O2_type,O2_point,O2_method,
O3,O3_type,O3_point,O3_method,O4,O4_type,O4_point,O4_method,
O5,O5_type,O5_point,O5_method,O6,O6_type,O6_point,O6_method,
O7,O7_type,O7_point,O7_method,O8,O8_type,O8_point,O8_method,
O9,O9_type,O9_point,O9_method,O10,O10_type,O10_pointn,O10_method,
Recruiting_status,Age_min,Age_max,Gender,Randomization]

import pandas as pd
df = pd.DataFrame(data)
excel_file = 'trial_ChiCTR.xlsx'

df.T.to_excel(excel_file, index=False)

# %%
### import for Clinicaltrial.gov 

# search terms in English
# long distance, remote, telehealth, internet, mobile health, mobile platform, virtual reality, mobile app, app, software intervention, software treatment, mini program, mobile program, digital therapeutic, digital therapy, digital intervention, digital treatment, digital health


# get clinical trials registration number 

url = []

class spider():
    def __init__(self):
        # url
        # self.url = 'https://www.chictr.org.cn/searchproj.html?page=2&title=%E8%BF%9C%E7%A8%8B&officialname=&subjectid=&regstatus=&regno=&secondaryid=&applier=&studyleader=&createyear=&sponsor=&secsponsor=&sourceofspends=&studyailment=&studyailmentcode=&studytype=&studystage=&studydesign=&recruitmentstatus=&gender=&agreetosign=&measure=&country=&province=&city=&institution=&institutionlevel=&intercode=&ethicalcommitteesanction=&whetherpublic=&minstudyexecutetime=&maxstudyexecutetime=&btngo=btn'
        self.opt = webdriver.ChromeOptions() 
        self.opt.add_experimental_option('excludeSwitches', ['enable-automation']) 
        self.browser = webdriver.Chrome(options=self.opt)
#         options = webdriver.ChromeOptions()  
#         options.add_experimental_option("prefs", {"profile.managed_default_content_settings.images": 2})

    def get_lc(self,url,j):
        self.browser.get(url)

#         wait = WebDriverWait(self.browser, 280)
#         wait.until(EC.presence_of_element_located((By.ID, 'topic')))

        # text_input = self.browser.find_element(By.ID, 'topic')
        # time.sleep(10)
        #self.browser.find_element(By.XPATH, '//*[@id="handle-search"]').click()
        time.sleep(1)
        if j==1:
            self.browser.find_element(By.XPATH, '//*[@id="main-content"]/ctg-search-results/div[2]/section/div[2]/div/div/div[2]/ctg-search-hit-card[1]/div/div[3]/header/a').click()
        elif j==2:
            self.browser.find_element(By.XPATH, '//*[@id="main-content"]/ctg-search-results/div[2]/section/div[2]/div/div/div[2]/ctg-search-hit-card[2]/div/div[3]/header/a').click()
        elif j==3:
            self.browser.find_element(By.XPATH, '//*[@id="main-content"]/ctg-search-results/div[2]/section/div[2]/div/div/div[2]/ctg-search-hit-card[3]/div/div[3]/header/a').click()
        elif j==4:
            self.browser.find_element(By.XPATH, '//*[@id="main-content"]/ctg-search-results/div[2]/section/div[2]/div/div/div[2]/ctg-search-hit-card[4]/div/div[3]/header/a').click()
        elif j==5:
            self.browser.find_element(By.XPATH, '//*[@id="main-content"]/ctg-search-results/div[2]/section/div[2]/div/div/div[2]/ctg-search-hit-card[5]/div/div[3]/header/a').click()
        elif j==6:
            self.browser.find_element(By.XPATH, '//*[@id="main-content"]/ctg-search-results/div[2]/section/div[2]/div/div/div[2]/ctg-search-hit-card[6]/div/div[3]/header/a').click()
        elif j==7:
            self.browser.find_element(By.XPATH, '//*[@id="main-content"]/ctg-search-results/div[2]/section/div[2]/div/div/div[2]/ctg-search-hit-card[7]/div/div[3]/header/a').click()
        elif j==8:
            self.browser.find_element(By.XPATH, '//*[@id="main-content"]/ctg-search-results/div[2]/section/div[2]/div/div/div[2]/ctg-search-hit-card[8]/div/div[3]/header/a').click()
        elif j==9:
            self.browser.find_element(By.XPATH, '//*[@id="main-content"]/ctg-search-results/div[2]/section/div[2]/div/div/div[2]/ctg-search-hit-card[9]/div/div[3]/header/a').click()
        elif j==10:
            self.browser.find_element(By.XPATH, '//*[@id="main-content"]/ctg-search-results/div[2]/section/div[2]/div/div/div[2]/ctg-search-hit-card[10]/div/div[3]/header/a').click()

        time.sleep(1)
    def get_data(self):
        #data=self.browser.page_source
        
#         browser = webdriver.Chrome(executable_path='path/to/chromedriver')
#         url_list.append(browser.current_url)
#         print(browser.current_url)
              
        try:
            RegistrationN_list.append(self.browser.find_element(By.XPATH,'//*[@id="main-content"]/ctg-study-details/section/ctg-study-details-top-info/div[4]/div[1]/span[2]').text)
            print('success')
        except NoSuchElementException:
            RegistrationN_list.append('NA')
            print('None')    
                              
if __name__ == '__main__':
    for i in range(1,25):
        print("现在是第{}页".format(i))
        #### change search terms
        url='https://clinicaltrials.gov/search?locStr=China&country=China&intr=telehealth&page={}'.format(i)
        s = spider()
        for j in range(1,11):
            print("现在是第{}个数据".format(j))           
            s.get_lc(url,j)
            s.get_data()




## define characteristics 

# basic characteristics
RegistrationN_list = [], DateR_list = [], ScientificT_list = [], Applicant_list = []
StudyL_list =[], SourceF_list = [], TargetD_list = [], StudyT_list = [], StudyP_list = [], StudyD_list = [], StudyO_list = []
StudyTi_from_list = [], StudyTi_to_list = [], RecruitTi_from_list = [], RecruitTi_to_list = []
Recruiting_status = [], Age_range = [], Gender = [], Randomization = [], Blind = []

# group, sample size, intervention
G1 = [], G1_Ssize = [], G1_intervention = [], G2 = [], G2_Ssize = [], G2_intervention = []
G3 = [], G3_Ssize = [], G3_intervention = [], G4 = [], G4_Ssize = [], G4_intervention = []
G5 = [], G5_Ssize = [], G5_intervention = []

# implementation site, level, location
S_hospital = [], S_level = [], S_Province = [], S1_hospital = [], S1_level = [], S1_Province = []
S2_hospital = [], S2_level = [], S2_Province = [], S3_hospital = [], S3_level = [], S3_Province = []
S4_hospital = [], S4_level = [], S4_Province = [], S5_hospital = [], S5_level = [], S5_Province = []
S6_hospital = [], S6_level = [], S6_Province = [], S7_hospital = [], S7_level = [], S7_Province = []
S8_hospital = [], S8_level = [], S8_Province = [], S9_hospital = [], S9_level = [], S9_Province = []

# outcome, type, time_point, method
O1 = [], O1_type = [], O1_point = [], O1_method = [], O2 = [], O2_type = [], O2_point = [], O2_method = []
O3 = [], O3_type = [], O3_point = [], O3_method = [], O4 = [], O4_type = [], O4_point = [], O4_method = []
O5 = [], O5_type = [], O5_point = [], O5_method = [], O6 = [], O6_type = [], O6_point = [], O6_method = []
O7 = [], O7_type = [], O7_point = [], O7_method = [], O8 = [], O8_type = [], O8_point = [], O8_method = []
O9 = [], O9_type = [], O9_point = [], O9_method = [], O10 = [], O10_type = [], O10_point = [], O10_method = []

# %%
import pandas as pd

data_list = pd.read_csv('ids_list.csv', header=None).T.values.tolist()

ids_list = [item for sublist in data_list for item in sublist]

ids_list

# %%
## load matching information

driver_path = 'path/to/chromedriver'  
browser = webdriver.Chrome()
browser.implicitly_wait(5)
    # url
    # self.url = 'https://www.chictr.org.cn/searchproj.html?page=2&title=%E8%BF%9C%E7%A8%8B&officialname=&subjectid=&regstatus=&regno=&secondaryid=&applier=&studyleader=&createyear=&sponsor=&secsponsor=&sourceofspends=&studyailment=&studyailmentcode=&studytype=&studystage=&studydesign=&recruitmentstatus=&gender=&agreetosign=&measure=&country=&province=&city=&institution=&institutionlevel=&intercode=&ethicalcommitteesanction=&whetherpublic=&minstudyexecutetime=&maxstudyexecutetime=&btngo=btn'
#     self.opt = webdriver.ChromeOptions()  
#     self.opt.add_experimental_option('excludeSwitches', ['enable-automation']) 
#     self.browser = webdriver.Chrome(options=self.opt)
#         options = webdriver.ChromeOptions()  
#         options.add_experimental_option("prefs", {"profile.managed_default_content_settings.images": 2})

# ids_list = ["NCT04909788","NCT06158425"]

for index, ids in enumerate(ids_list[1:], start=1):#155
    
    print(f"第{index}个开始")
    url = f"https://clinicaltrials.gov/study/{ids}"
    browser.get(url)
    
    try:
        RegistrationN_list.append(browser.find_element(By.XPATH,'//*[@id="main-content"]/ctg-study-details/section/ctg-study-details-top-info/div[3]/div[1]/span[2]').text)
        print('success')
    except NoSuchElementException:
        RegistrationN_list.append('NA')
        print('None')
    
    try:
        DateR_list.append(browser.find_element(By.XPATH,'//*[@id="study-record-dates"]/ctg-study-record-dates/div[2]/div[1]/ctg-study-record-dates-table/div[2]/div[3]/div[2]').text)
        print('success')
    except NoSuchElementException:
        DateR_list.append('NA')
        print('None')
    try:
        StudyL_list.append(browser.find_element(By.XPATH,'//*[@id="contacts-and-locations"]/ctg-study-contacts-and-locations/div/div/div/ctg-study-contact-info/p[1]/span').text)
        print('success')
    except NoSuchElementException:
        StudyL_list.append('NA')
        print('None')
    try:
        AffiliationL_list.append(browser.find_element(By.XPATH,'//*[@id="main-content"]/ctg-study-details/section/ctg-study-details-top-info/div[3]/div[3]/ctg-responsible-party/span[2]').text)
        print('success')
    except NoSuchElementException:
        AffiliationL_list.append('NA')
        print('None')
    try:
        SourceF_list.append(browser.find_element(By.XPATH,'//*[@id="main-content"]/ctg-study-details/section/ctg-study-details-top-info/div[3]/div[2]/span[2]').text)
        print('success')
    except NoSuchElementException:
        SourceF_list.append('NA')
        print('None')
    try:
        TargetD_list.append(browser.find_element(By.XPATH,'//*[@id="study-overview"]/ctg-study-overview/div/div/div[1]/ctg-conditions/div/div[1]/span[1]').text)
        print('success')
    except NoSuchElementException:
        TargetD_list.append('NA')
        print('None')
    try:
        TargetD_list1.append(browser.find_element(By.XPATH,'//*[@id="study-overview"]/ctg-study-overview/div/div/div[1]/ctg-conditions/div/div[2]/span[1]').text)
        print('success')
    except NoSuchElementException:
        TargetD_list1.append('NA')
        print('None')
    try:
        TargetD_list2.append(browser.find_element(By.XPATH,'//*[@id="study-overview"]/ctg-study-overview/div/div/div[1]/ctg-conditions/div/div[3]/span[1]').text)
        print('success')
    except NoSuchElementException:
        TargetD_list2.append('NA')
        print('None')
    try:
        StudyT_list.append(browser.find_element(By.XPATH,'//*[@id="study-overview"]/ctg-study-overview/div/div/div[2]/div/div[3]/ctg-enum-value/span').text)
        print('success')
    except NoSuchElementException:
        StudyT_list.append('NA')
        print('None') 
    try:
        StudyP_list.append(browser.find_element(By.XPATH,'//*[@id="study-overview"]/ctg-study-overview/div/div/div[2]/div/div[4]/ctg-enum-value/span').text)
        print('success')
    except NoSuchElementException:
        StudyP_list.append('NA')
        print('None')
    try:
        StudyD_list.append(browser.find_element(By.XPATH,'//*[@id="howStudyDesigned"]/div[1]/div/div/div[2]/div[3]/span/ctg-enum-value/span').text)
        print('success')
    except NoSuchElementException:
        StudyD_list.append('NA')
        print('None')        
    try:
        StudyO_list.append(browser.find_element(By.XPATH,'//*[@id="howStudyDesigned"]/div[1]/div/div/div[2]/div[1]/span/ctg-enum-value/span').text)
        print('success')
    except NoSuchElementException:
        StudyO_list.append('NA')
        print('None')        
    try:
        StudyTi_from_list.append(browser.find_element(By.XPATH,'//*[@id="study-overview"]/ctg-study-overview/div/div/div[2]/div/div[1]/div[1]/span').text)
        print('success')
    except NoSuchElementException:
        StudyTi_from_list.append('NA')
        print('None')           
    try:
        StudyTi_to_list.append(browser.find_element(By.XPATH,'//*[@id="study-overview"]/ctg-study-overview/div/div/div[2]/div/div[1]/div[3]/span').text)
        print('success')
    except NoSuchElementException:
        StudyTi_to_list.append('NA')
        print('None')            
    try:
        G1.append(browser.find_element(By.XPATH,'//*[@id="study-overview"]/ctg-study-overview/div/div/div[1]/div[5]/div[2]/ul/li[1]/ctg-enum-value/span').text)
        print('success')
    except NoSuchElementException:
        G1.append('NA')
        print('None')        
    try:
        G1_Ssize.append(browser.find_element(By.XPATH,'//*[@id="study-overview"]/ctg-study-overview/div/div/div[2]/div/div[2]/div[2]/span').text)
        print('success')
    except NoSuchElementException:
        G1_Ssize.append('NA')
        print('None')   
    try:
        G1_intervention.append(browser.find_element(By.XPATH,'//*[@id="study-overview"]/ctg-study-overview/div/div/div[1]/div[5]/div[2]/ul/li[1]/span').text)
        print('success')
    except NoSuchElementException:
        G1_intervention.append('NA')
        print('None')    
    try:
        G2.append(browser.find_element(By.XPATH,'//*[@id="study-overview"]/ctg-study-overview/div/div/div[1]/div[5]/div[2]/ul/li[2]/ctg-enum-value/span').text)
        print('success')
    except NoSuchElementException:
        G2.append('NA')
        print('None')        
    try:
        G2_intervention.append(browser.find_element(By.XPATH,'//*[@id="study-overview"]/ctg-study-overview/div/div/div[1]/div[5]/div[2]/ul/li[2]/span').text)
        print('success')
    except NoSuchElementException:
        G2_intervention.append('NA')
        print('None') 
    try:
        G3.append(browser.find_element(By.XPATH,'//*[@id="study-overview"]/ctg-study-overview/div/div/div[1]/div[5]/div[2]/ul/li[3]/ctg-enum-value/span').text)
        print('success')
    except NoSuchElementException:
        G3.append('NA')
        print('None')    
    try:
        G3_intervention.append(browser.find_element(By.XPATH,'//*[@id="study-overview"]/ctg-study-overview/div/div/div[1]/div[5]/div[2]/ul/li[3]/span').text)
        print('success')
    except NoSuchElementException:
        G3_intervention.append('NA')
        print('None')        
    try:
        G4.append(browser.find_element(By.XPATH,'//*[@id="study-overview"]/ctg-study-overview/div/div/div[1]/div[5]/div[2]/ul/li[4]/ctg-enum-value/span').text)
        print('success')
    except NoSuchElementException:
        G4.append('NA')
        print('None') 
    try:
        G4_intervention.append(browser.find_element(By.XPATH,'//*[@id="study-overview"]/ctg-study-overview/div/div/div[1]/div[5]/div[2]/ul/li[4]/span').text)
        print('success')
    except NoSuchElementException:
        G4_intervention.append('NA')
        print('None')        
    try:
        G5.append(browser.find_element(By.XPATH,'//*[@id="study-overview"]/ctg-study-overview/div/div/div[1]/div[5]/div[2]/ul/li[5]/ctg-enum-value/span').text)
        print('success')
    except NoSuchElementException:
        G5.append('NA')
        print('None')    
    try:
        G5_intervention.append(browser.find_element(By.XPATH,'//*[@id="study-overview"]/ctg-study-overview/div/div/div[1]/div[5]/div[2]/ul/li[5]/span').text)
        print('success')
    except NoSuchElementException:
        G5_intervention.append('NA')
        print('None')        
    try:
        S1_hospital.append(browser.find_element(By.XPATH,'//*[@id="study-location-item-0"]/a/div[2]/span').text)
        print('success')
    except NoSuchElementException:
        S1_hospital.append('NA')
        print('None')     
    try:
        S1_Province.append(browser.find_element(By.XPATH,'//*[@id="study-location-item-0"]/a/div[1]/b/span').text)
        print('success')
    except NoSuchElementException:
        S1_Province.append('NA')
        print('None')        
    try:
        S2_hospital.append(browser.find_element(By.XPATH,'//*[@id="study-location-item-1"]/a/div[2]/b/span').text)
        print('success')
    except NoSuchElementException:
        S2_hospital.append('NA')
        print('None')     
    try:
        S2_Province.append(browser.find_element(By.XPATH,'//*[@id="study-location-item-1"]/a/div[1]/b/span').text)
        print('success')
    except NoSuchElementException:
        S2_Province.append('NA')
        print('None')        
    try:
        S3_hospital.append(browser.find_element(By.XPATH,'//*[@id="study-location-item-2"]/a/div[2]/b/span').text)
        print('success')
    except NoSuchElementException:
        S3_hospital.append('NA')
        print('None')     
    try:
        S3_Province.append(browser.find_element(By.XPATH,'//*[@id="study-location-item-2"]/a/div[1]/b/span').text)
        print('success')
    except NoSuchElementException:
        S3_Province.append('NA')
        print('None')  
    try:
        S4_hospital.append(browser.find_element(By.XPATH,'//*[@id="study-location-item-3"]/a/div[2]/b/span').text)
        print('success')
    except NoSuchElementException:
        S4_hospital.append('NA')
        print('None')     
    try:
        S4_Province.append(browser.find_element(By.XPATH,'//*[@id="study-location-item-3"]/a/div[1]/b/span').text)
        print('success')
    except NoSuchElementException:
        S4_Province.append('NA')
        print('None')          
    try:
        S5_hospital.append(browser.find_element(By.XPATH,'//*[@id="study-location-item-4"]/a/div[2]/b/span').text)
        print('success')
    except NoSuchElementException:
        S5_hospital.append('NA')
        print('None')     
    try:
        S5_Province.append(browser.find_element(By.XPATH,'//*[@id="study-location-item-4"]/a/div[1]/b/span').text)
        print('success')
    except NoSuchElementException:
        S5_Province.append('NA')
        print('None')          
    try:
        S6_hospital.append(browser.find_element(By.XPATH,'//*[@id="study-location-item-5"]/a/div[2]/b/span').text)
        print('success')
    except NoSuchElementException:
        S6_hospital.append('NA')
        print('None')     
    try:
        S6_Province.append(browser.find_element(By.XPATH,'//*[@id="study-location-item-5"]/a/div[1]/b/span').text)
        print('success')
    except NoSuchElementException:
        S6_Province.append('NA')
        print('None')         
    try:
        S7_hospital.append(browser.find_element(By.XPATH,'//*[@id="study-location-item-6"]/a/div[2]/b/span').text)
        print('success')
    except NoSuchElementException:
        S7_hospital.append('NA')
        print('None')     
    try:
        S7_Province.append(browser.find_element(By.XPATH,'//*[@id="study-location-item-6"]/a/div[1]/b/span').text)
        print('success')
    except NoSuchElementException:
        S7_Province.append('NA')
        print('None')         
    try:
        S8_hospital.append(browser.find_element(By.XPATH,'//*[@id="study-location-item-7"]/a/div[2]/b/span').text)
        print('success')
    except NoSuchElementException:
        S8_hospital.append('NA')
        print('None')     
    try:
        S8_Province.append(browser.find_element(By.XPATH,'//*[@id="study-location-item-7"]/a/div[1]/b/span').text)
        print('success')
    except NoSuchElementException:
        S8_Province.append('NA')
        print('None')          
    try:
        S9_hospital.append(browser.find_element(By.XPATH,'//*[@id="study-location-item-8"]/a/div[2]/b/span').text)
        print('success')
    except NoSuchElementException:
        S9_hospital.append('NA')
        print('None')     
    try:
        S9_Province.append(browser.find_element(By.XPATH,'//*[@id="study-location-item-8"]/a/div[1]/b/span').text)
        print('success')
    except NoSuchElementException:
        S9_Province.append('NA')
        print('None')          
    try:
        S10_hospital.append(browser.find_element(By.XPATH,'//*[@id="study-location-item-9"]/a/div[2]/b/span').text)
        print('success')
    except NoSuchElementException:
        S10_hospital.append('NA')
        print('None')     
    try:
        S10_Province.append(browser.find_element(By.XPATH,'//*[@id="study-location-item-9"]/a/div[1]/b/span').text)
        print('success')
    except NoSuchElementException:
        S10_Province.append('NA')
        print('None')                 
    try:
        O1.append(browser.find_element(By.XPATH,'//*[@id="whatStudyMeasure"]/ctg-outcomes-module/ctg-outcomes[1]/div[2]/div/table/tbody/tr[1]/td[1]').text)
        print('success')
    except NoSuchElementException:
        O1.append('NA')
        print('None')     
    try:
        O1_type.append(browser.find_element(By.XPATH,'//*[@id="whatStudyMeasure"]/ctg-outcomes-module/ctg-outcomes[1]/div[1]').text)
        print('success')
    except NoSuchElementException:
        O1_type.append('NA')
        print('None')      
    try:
        O1_point.append(browser.find_element(By.XPATH,'//*[@id="whatStudyMeasure"]/ctg-outcomes-module/ctg-outcomes[1]/div[2]/div/table/tbody/tr[1]/td[3]').text)
        print('success')
    except NoSuchElementException:
        O1_point.append('NA')
        print('None')  
    try:
        O1_method.append(browser.find_element(By.XPATH,'//*[@id="whatStudyMeasure"]/ctg-outcomes-module/ctg-outcomes[1]/div[2]/div/table/tbody/tr[1]/td[2]').text)
        print('success')
    except NoSuchElementException:
        O1_method.append('NA')
        print('None')                  
    try:
        O2.append(browser.find_element(By.XPATH,'//*[@id="whatStudyMeasure"]/ctg-outcomes-module/ctg-outcomes[1]/div[2]/div/table/tbody/tr[2]/td[1]').text)
        print('success')
    except NoSuchElementException:
        O2.append('NA')
        print('None')               
    try:
        O2_type.append(browser.find_element(By.XPATH,'//*[@id="whatStudyMeasure"]/ctg-outcomes-module/ctg-outcomes[1]/div[1]').text)
        print('success')
    except NoSuchElementException:
        O2_type.append('NA')
        print('None')      
    try:
        O2_point.append(browser.find_element(By.XPATH,'//*[@id="whatStudyMeasure"]/ctg-outcomes-module/ctg-outcomes[1]/div[2]/div/table/tbody/tr[2]/td[3]').text)
        print('success')
    except NoSuchElementException:
        O2_point.append('NA')
        print('None')  
    try:
        O2_method.append(browser.find_element(By.XPATH,'//*[@id="whatStudyMeasure"]/ctg-outcomes-module/ctg-outcomes[1]/div[2]/div/table/tbody/tr[2]/td[2]').text)
        print('success')
    except NoSuchElementException:
        O2_method.append('NA')
        print('None')        
    try:
        O3.append(browser.find_element(By.XPATH,'//*[@id="whatStudyMeasure"]/ctg-outcomes-module/ctg-outcomes[1]/div[2]/div/table/tbody/tr[3]/td[1]').text)
        print('success')
    except NoSuchElementException:
        O3.append('NA')
        print('None')   
    try:
        O3_type.append(browser.find_element(By.XPATH,'//*[@id="whatStudyMeasure"]/ctg-outcomes-module/ctg-outcomes[1]/div[1]').text)
        print('success')
    except NoSuchElementException:
        O3_type.append('NA')
        print('None')      
    try:
        O3_point.append(browser.find_element(By.XPATH,'//*[@id="whatStudyMeasure"]/ctg-outcomes-module/ctg-outcomes[1]/div[2]/div/table/tbody/tr[3]/td[3]').text)
        print('success')
    except NoSuchElementException:
        O3_point.append('NA')
        print('None')  
    try:
        O3_method.append(browser.find_element(By.XPATH,'//*[@id="whatStudyMeasure"]/ctg-outcomes-module/ctg-outcomes[1]/div[2]/div/table/tbody/tr[3]/td[2]').text)
        print('success')
    except NoSuchElementException:
        O3_method.append('NA')
        print('None') 
    try:
        O4.append(browser.find_element(By.XPATH,'//*[@id="whatStudyMeasure"]/ctg-outcomes-module/ctg-outcomes[1]/div[2]/div/table/tbody/tr[4]/td[1]').text)
        print('success')
    except NoSuchElementException:
        O4.append('NA')
        print('None')   
    try:
        O4_type.append(browser.find_element(By.XPATH,'//*[@id="whatStudyMeasure"]/ctg-outcomes-module/ctg-outcomes[1]/div[1]').text)
        print('success')
    except NoSuchElementException:
        O4_type.append('NA')
        print('None')      
    try:
        O4_point.append(browser.find_element(By.XPATH,'//*[@id="whatStudyMeasure"]/ctg-outcomes-module/ctg-outcomes[1]/div[2]/div/table/tbody/tr[4]/td[3]').text)
        print('success')
    except NoSuchElementException:
        O4_point.append('NA')
        print('None')  
    try:
        O4_method.append(browser.find_element(By.XPATH,'//*[@id="whatStudyMeasure"]/ctg-outcomes-module/ctg-outcomes[1]/div[2]/div/table/tbody/tr[4]/td[2]').text)
        print('success')
    except NoSuchElementException:
        O4_method.append('NA')
        print('None') 
    try:
        O5.append(browser.find_element(By.XPATH,'//*[@id="whatStudyMeasure"]/ctg-outcomes-module/ctg-outcomes[1]/div[2]/div/table/tbody/tr[5]/td[1]').text)
        print('success')
    except NoSuchElementException:
        O5.append('NA')
        print('None')   
    try:
        O5_type.append(browser.find_element(By.XPATH,'//*[@id="whatStudyMeasure"]/ctg-outcomes-module/ctg-outcomes[1]/div[1]').text)
        print('success')
    except NoSuchElementException:
        O5_type.append('NA')
        print('None')      
    try:
        O5_point.append(browser.find_element(By.XPATH,'//*[@id="whatStudyMeasure"]/ctg-outcomes-module/ctg-outcomes[1]/div[2]/div/table/tbody/tr[5]/td[3]').text)
        print('success')
    except NoSuchElementException:
        O5_point.append('NA')
        print('None')  
    try:
        O5_method.append(browser.find_element(By.XPATH,'//*[@id="whatStudyMeasure"]/ctg-outcomes-module/ctg-outcomes[1]/div[2]/div/table/tbody/tr[5]/td[2]').text)
        print('success')
    except NoSuchElementException:
        O5_method.append('NA')
        print('None')                                  
    try:
        O6.append(browser.find_element(By.XPATH,'//*[@id="whatStudyMeasure"]/ctg-outcomes-module/ctg-outcomes[2]/div[2]/div/table/tbody/tr[1]/td[1]').text)
        print('success')
    except NoSuchElementException:
        O6.append('NA')
        print('None')     
    try:
        O6_type.append(browser.find_element(By.XPATH,'//*[@id="whatStudyMeasure"]/ctg-outcomes-module/ctg-outcomes[2]/div[1]').text)
        print('success')
    except NoSuchElementException:
        O6_type.append('NA')
        print('None')      
    try:
        O6_point.append(browser.find_element(By.XPATH,'//*[@id="whatStudyMeasure"]/ctg-outcomes-module/ctg-outcomes[2]/div[2]/div/table/tbody/tr[1]/td[3]').text)
        print('success')
    except NoSuchElementException:
        O6_point.append('NA')
        print('None')  
    try:
        O6_method.append(browser.find_element(By.XPATH,'//*[@id="whatStudyMeasure"]/ctg-outcomes-module/ctg-outcomes[2]/div[2]/div/table/tbody/tr[1]/td[2]').text)
        print('success')
    except NoSuchElementException:
        O6_method.append('NA')
        print('None')                  
    try:
        O7.append(browser.find_element(By.XPATH,'//*[@id="whatStudyMeasure"]/ctg-outcomes-module/ctg-outcomes[2]/div[2]/div/table/tbody/tr[2]/td[1]').text)
        print('success')
    except NoSuchElementException:
        O7.append('NA')
        print('None')               
    try:
        O7_type.append(browser.find_element(By.XPATH,'//*[@id="whatStudyMeasure"]/ctg-outcomes-module/ctg-outcomes[2]/div[1]').text)
        print('success')
    except NoSuchElementException:
        O7_type.append('NA')
        print('None')      
    try:
        O7_point.append(browser.find_element(By.XPATH,'//*[@id="whatStudyMeasure"]/ctg-outcomes-module/ctg-outcomes[2]/div[2]/div/table/tbody/tr[2]/td[3]').text)
        print('success')
    except NoSuchElementException:
        O7_point.append('NA')
        print('None')  
    try:
        O7_method.append(browser.find_element(By.XPATH,'//*[@id="whatStudyMeasure"]/ctg-outcomes-module/ctg-outcomes[2]/div[2]/div/table/tbody/tr[2]/td[2]').text)
        print('success')
    except NoSuchElementException:
        O7_method.append('NA')
        print('None')        
    try:
        O8.append(browser.find_element(By.XPATH,'//*[@id="whatStudyMeasure"]/ctg-outcomes-module/ctg-outcomes[2]/div[2]/div/table/tbody/tr[3]/td[1]').text)
        print('success')
    except NoSuchElementException:
        O8.append('NA')
        print('None')   
    try:
        O8_type.append(browser.find_element(By.XPATH,'//*[@id="whatStudyMeasure"]/ctg-outcomes-module/ctg-outcomes[2]/div[1]').text)
        print('success')
    except NoSuchElementException:
        O8_type.append('NA')
        print('None')      
    try:
        O8_point.append(browser.find_element(By.XPATH,'//*[@id="whatStudyMeasure"]/ctg-outcomes-module/ctg-outcomes[2]/div[2]/div/table/tbody/tr[3]/td[3]').text)
        print('success')
    except NoSuchElementException:
        O8_point.append('NA')
        print('None')  
    try:
        O8_method.append(browser.find_element(By.XPATH,'//*[@id="whatStudyMeasure"]/ctg-outcomes-module/ctg-outcomes[2]/div[2]/div/table/tbody/tr[3]/td[2]').text)
        print('success')
    except NoSuchElementException:
        O8_method.append('NA')
        print('None') 
    try:
        O9.append(browser.find_element(By.XPATH,'//*[@id="whatStudyMeasure"]/ctg-outcomes-module/ctg-outcomes[2]/div[2]/div/table/tbody/tr[4]/td[1]').text)
        print('success')
    except NoSuchElementException:
        O9.append('NA')
        print('None')   
    try:
        O9_type.append(browser.find_element(By.XPATH,'//*[@id="whatStudyMeasure"]/ctg-outcomes-module/ctg-outcomes[2]/div[1]').text)
        print('success')
    except NoSuchElementException:
        O9_type.append('NA')
        print('None')      
    try:
        O9_point.append(browser.find_element(By.XPATH,'//*[@id="whatStudyMeasure"]/ctg-outcomes-module/ctg-outcomes[2]/div[2]/div/table/tbody/tr[4]/td[3]').text)
        print('success')
    except NoSuchElementException:
        O9_point.append('NA')
        print('None')  
    try:
        O9_method.append(browser.find_element(By.XPATH,'//*[@id="whatStudyMeasure"]/ctg-outcomes-module/ctg-outcomes[2]/div[2]/div/table/tbody/tr[4]/td[2]').text)
        print('success')
    except NoSuchElementException:
        O9_method.append('NA')
        print('None') 
    try:
        O10.append(browser.find_element(By.XPATH,'//*[@id="whatStudyMeasure"]/ctg-outcomes-module/ctg-outcomes[2]/div[2]/div/table/tbody/tr[5]/td[1]').text)
        print('success')
    except NoSuchElementException:
        O10.append('NA')
        print('None')   
    try:
        O10_type.append(browser.find_element(By.XPATH,'//*[@id="whatStudyMeasure"]/ctg-outcomes-module/ctg-outcomes[2]/div[1]').text)
        print('success')
    except NoSuchElementException:
        O10_type.append('NA')
        print('None')      
    try:
        O10_point.append(browser.find_element(By.XPATH,'//*[@id="whatStudyMeasure"]/ctg-outcomes-module/ctg-outcomes[2]/div[2]/div/table/tbody/tr[5]/td[3]').text)
        print('success')
    except NoSuchElementException:
        O10_point.append('NA')
        print('None')  
    try:
        O10_method.append(browser.find_element(By.XPATH,'//*[@id="whatStudyMeasure"]/ctg-outcomes-module/ctg-outcomes[2]/div[2]/div/table/tbody/tr[5]/td[2]').text)
        print('success')
    except NoSuchElementException:
        O10_method.append('NA')
        print('None')
              
    try:
        Recruiting_status.append(browser.find_element(By.XPATH,'//*[@id="main-content"]/ctg-study-details/section/ctg-study-details-top-info/div[2]/div/ctg-overall-status/ctg-enum-value/span').text)
        print('success')
    except NoSuchElementException:
        Recruiting_status.append('NA')
        print('None')         
    try:
        Age_range.append(browser.find_element(By.XPATH,'//*[@id="participation-criteria"]/ctg-participation-criteria/div[2]/div/div[2]/div[2]/div[2]/ctg-standard-age/span[1]').text)
        print('success')
    except NoSuchElementException:
        Age_range.append('NA')
        print('None')  
    try:
        Gender.append(browser.find_element(By.XPATH,'//*[@id="participation-criteria"]/ctg-participation-criteria/div[2]/div/div[2]/div[2]/div[4]/ctg-enum-value/span').text)
        print('success')
    except NoSuchElementException:
        Gender.append('NA')
        print('None')                  
    try:
        Randomization.append(browser.find_element(By.XPATH,'//*[@id="howStudyDesigned"]/div[1]/div/div/div[2]/div[2]/span/ctg-enum-value/span').text)
        print('success')
    except NoSuchElementException:
        Randomization.append('NA')
        print('None') 
    try:
        Blind.append(browser.find_element(By.XPATH,'//*[@id="howStudyDesigned"]/div[1]/div/div/div[2]/div[4]/span/ctg-enum-value/span').text)
        print('success')
    except NoSuchElementException:
        Blind.append('NA')
        print('None')

# %%
data = [RegistrationN_list,StudyL_list,AffiliationL_list,SourceF_list,TargetD_list,TargetD_list1,TargetD_list2,
StudyT_list,StudyP_list,StudyD_list,StudyO_list,StudyTi_from_list,StudyTi_to_list,                   
G1,G1_Ssize,G1_intervention,G2,G2_intervention,G3,G3_intervention,
G4,G4_intervention,G5,G5_intervention,
S1_hospital,S1_Province,S2_hospital,S2_Province,S3_hospital,S3_Province,S4_hospital,S4_Province,S5_hospital,S5_Province,
O1,O1_type,O1_point,O1_method,O2,O2_type,O2_point,O2_method,
O3,O3_type,O3_point,O3_method,O4,O4_type,O4_point,O4_method,
O5,O5_type,O5_point,O5_method,O6,O6_type,O6_point,O6_method,
O7,O7_type,O7_point,O7_method,O8,O8_type,O8_point,O8_method,
O9,O9_type,O9_point,O9_method,O10,O10_type,O10_point,O10_method,
Recruiting_status,Age_range,Gender,Randomization,Blind]

df = pd.DataFrame(data)
excel_file = 'trial_gov.xlsx'

df.T.to_excel(excel_file, index=False)
